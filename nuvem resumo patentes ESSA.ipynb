# %%
# certifique-se de ter o arquivo nuvem.txt (salvo no formato CSV no excel) no diretorio corrente:

# the;1;47120
# a;2;30371
# of;3;23347
# and;4;17060
# to;5;15018
# is;6;13732
# for;7;13553
# method;8;9878

import random

frequencia_palavras = {}
with open('nuvemtitulosfinal2024essa.txt', 'r') as arquivo:
    for linha in arquivo:
        partes = linha.strip().split(';')
        if len(partes) == 3:
            palavra = partes[0]
            quantidade = int(partes[2])
            if palavra in frequencia_palavras:
                frequencia_palavras[palavra] += quantidade
            else:
                frequencia_palavras[palavra] = quantidade

# Converta o dicionário em uma lista de tuplas (palavra, frequência)
frequencia_lista = [(palavra, frequencia) for palavra, frequencia in frequencia_palavras.items()]

# Ordene a lista de frequência com base na frequência (do maior para o menor)
frequencia_lista.sort(key=lambda x: x[1], reverse=True)

# Exiba a lista de frequência
for palavra, frequencia in frequencia_lista:
    print(f'{palavra}: {frequencia}')

# Inicialize uma lista para armazenar as palavras repetidas
palavras_repetidas = []

# Crie a lista de palavras repetidas com base na frequência
for palavra, frequencia in frequencia_palavras.items():
    k = int(frequencia/3)
    palavras_repetidas.extend([palavra] * k)
    
# embaralhar a lista palavras repetidas
random.shuffle(palavras_repetidas)

# Crie uma string juntando as palavras repetidas
text = ' '.join(palavras_repetidas)

# print(text)
# Out:
# information: 2025
# Method: 1635
# involves: 1593
# data: 1185
# based: 1085
# model: 1059
# image: 897
# learning: 782
# label: 737
# network: 726
# training: 588
# obtaining: 550
# target: 494
# using: 472
# Neural: 407
# index: 386
# according: 379
# system: 366
# set: 361
# user: 356
# device: 306
# result: 305
# classification: 303
# processing: 301
# performing: 285
# artificial: 282
# text: 279
# with: 275
# determining: 271
# deep: 261
# sample: 260
# generating: 257
# machine: 255
# intelligence: 253
# obtain: 249
# detection: 223
# that: 201
# feature: 198
# prediction: 197
# module: 190
# first: 188
# corresponding: 185
# from: 180
# supervised: 178
# inputting: 178
# object: 173
# unit: 167
# value: 163
# evaluation: 162
# segmentation: 150
# comprises: 147
# electronic: 144
# labeling: 141
# multi: 139
# identification: 138
# identifying: 137
# analysis: 136
# recognition: 135
# service: 134
# each: 134
# process: 133
# characteristic: 129
# input: 127
# vector: 124
# pre: 123
# field: 122
# video: 121
# semantic: 119
# extracting: 119
# intelligent: 117
# Computer: 117
# detecting: 114
# second: 110
# sorting: 109
# medical: 105
# constructing: 103
# calculating: 103
# area: 103
# trained: 101
# risk: 99
# type: 95
# establishing: 95
# where: 94
# through: 94
# images: 94
# time: 93
# classifying: 93
# algorithm: 93
# position: 91
# management: 91
# recommendation: 90
# convolutional: 86
# tag: 85
# preset: 85
# multiple: 85
# Database: 85
# mining: 84
# predicting: 82
# which: 81
# operation: 81
# apparatus: 81
# output: 80
# terminal: 79
# product: 79
# picture: 79
# decision: 79
# vehicle: 78
# loss: 78
# knowledge: 78
# cloud: 77
# content: 76
# used: 75
# marking: 75
# test: 74
# providing: 74
# outputting: 74
# platform: 73
# parameter: 71
# technology: 69
# semi: 69
# receiving: 69
# map: 68
# function: 68
# extraction: 68
# selecting: 67
# probability: 67
# monitoring: 67
# point: 66
# level: 66
# collecting: 66
# category: 66
# task: 65
# entity: 65
# or: 64
# analyzing: 64
# self: 63
# server: 62
# behavior: 62
# word: 61
# search: 61
# processed: 61
# obtained: 61
# defect: 61
# sequence: 60
# recommending: 60
# between: 60
# attribute: 60
# graph: 58
# power: 57
# labeled: 57
# final: 56
# evaluating: 56
# score: 55
# node: 55
# utilizing: 54
# matching: 54
# human: 54
# frame: 54
# domain: 54
# Automatic: 54
# rule: 53
# face: 53
# document: 53
# storing: 52
# processor: 52
# fusion: 52
# control: 52
# parameters: 51
# detected: 51
# weight: 50
# original: 50
# combining: 50
# similarity: 49
# real: 49
# quality: 49
# display: 49
# computing: 49
# classifier: 49
# state: 48
# generate: 48
# updating: 47
# enterprise: 47
# disease: 47
# big: 47
# tree: 46
# sensing: 46
# related: 46
# dimensional: 46
# use: 45
# language: 45
# labels: 45
# item: 45
# sub: 44
# structure: 44
# space: 44
# signal: 44
# non: 44
# business: 44
# whether: 43
# warning: 43
# storage: 43
# query: 43
# key: 43
# character: 43
# arrangement: 43
# application: 43
# unsupervised: 42
# mode: 42
# diagnosis: 42
# candidate: 42
# an: 42
# after: 42
# when: 41
# source: 41
# scene: 41
# predicted: 41
# large: 41
# features: 41
# client: 41
# abnormal: 41
# support: 40
# number: 40
# flow: 40
# financial: 40
# file: 40
# Distribution: 40
# body: 40
# acquiring: 40
# pushing: 39
# organization: 39
# models: 39
# group: 39
# displaying: 39
# current: 39
# remote: 38
# layer: 38
# judging: 38
# high: 38
# generated: 38
# results: 37
# generation: 37
# associated: 37
# region: 36
# patient: 36
# end: 36
# different: 36
# condition: 36
# three: 35
# social: 35
# relationship: 35
# list: 35
# initial: 35
# at: 35
# resource: 34
# ontology: 34
# interface: 34
# action: 34
# train: 33
# standard: 33
# sentence: 33
# retrieval: 33
# push: 33
# performance: 33
# emotion: 33
# connected: 33
# automatically: 33
# two: 32
# threshold: 32
# sending: 32
# samples: 32
# robot: 32
# matrix: 32
# event: 32
# configured: 32
# transfer: 31
# searching: 31
# pedestrian: 31
# identified: 31
# component: 31
# adjusting: 31
# visual: 30
# structured: 30
# specific: 30
# optimizing: 30
# collected: 30
# clustering: 30
# are: 30
# template: 29
# portrait: 29
# line: 29
# interest: 29
# includes: 29
# degree: 29
# building: 29
# useful: 28
# transmitting: 28
# safety: 28
# representation: 28
# record: 28
# production: 28
# marked: 28
# fault: 28
# description: 28
# depth: 28
# construction: 28
# provided: 27
# person: 27
# perform: 27
# new: 27
# natural: 27
# industrial: 27
# dividing: 27
# class: 27
# attention: 27
# table: 26
# stored: 26
# realizing: 26
# random: 26

# %%
import spacy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from spacy.lang.en.stop_words import STOP_WORDS
#from spacy.lang.pt.stop_words import STOP_WORDS
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

#elimine stop words em inglês
nlp = spacy.load("en_core_web_sm")
#nlp = spacy.load("pt_core_news_sm")
doc = nlp(text)
palavras_sem_stop_words = [token.text for token in doc if not token.is_stop]
texto = " ".join(palavras_sem_stop_words)

# Crie a nuvem de palavras
wordcloud = WordCloud(
    background_color='white', 
    font_path='arial.ttf', 
    width=2000, 
    height=1000, 
    collocations=False,  # Desativa a combinação de palavras
    random_state=42      # Define um estado aleatório para as cores
).generate(texto)

# Defina um esquema de cores personalizado (exemplo: vermelho, verde e azul)
colors = ["red", "green", "blue", "black", "pink", "orange", "gray", "navy"]

# Crie uma imagem de array de cores com base na nuvem de palavras
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return random.choice(colors)

wordcloud = WordCloud(
    background_color='white',
    font_path='arial.ttf',
    width=2000,
    height=1000,
    collocations=False,
    random_state=42
).generate(texto)
wordcloud.recolor(color_func=color_func)  # Aplica o esquema de cores personalizado

# Exiba a nuvem de palavras
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Paula
# [nltk_data]     Cotrim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#!pip install spacy
#!pip install wordcloud
#!python -m spacy download en_core_web_sm
